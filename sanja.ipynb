# %%
# Install the ultralytics package using pip. The '%' sign is a Jupyter notebook
# "magic" command that allows you to run shell commands in a notebook cell.
# %pip install ultralytics

# Import the ultralytics package. This package contains the YOLO model and other utilities.
import ultralytics

# Import the YOLO class from the ultralytics package. This class represents the YOLO model.
from ultralytics import YOLO

# Import the settings module from the ultralytics package. This module contains
# settings and configuration options for the YOLO model.
from ultralytics import settings

# Import the os module. This module provides functions for interacting with the operating system.
import os

# Import the Image and display functions from the IPython.display module. These functions
# are used to display images in a Jupyter notebook.
from IPython.display import Image, display

# Import the display module from the IPython package. This module contains functions
# for controlling the output display in a Jupyter notebook.
from IPython import display

# Clear the output of the current cell.
display.clear_output()

# Run checks in the ultralytics package. This function might check for things like
# required dependencies or specific hardware requirements.
ultralytics.checks()

from torch.utils import tensorboard
# Out:
# Ultralytics YOLOv8.0.232 🚀 Python-3.11.5 torch-2.1.2 CPU (Apple M2 Pro)
# Setup complete ✅ (12 CPUs, 16.0 GB RAM, 575.5/926.4 GB disk)

# %%
#@title Select YOLOv8 🚀 logger {run: 'auto'}
logger = 'TensorBoard' #@param ['Comet', 'TensorBoard']

if logger == 'Comet':
  # %pip install -q comet_ml
  import comet_ml; comet_ml.init()
elif logger == 'TensorBoard':
  # %load_ext tensorboard
  # %tensorboard --logdir runs/train
# Out:
#       <iframe id="tensorboard-frame-83ad0ae9b03292d" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-83ad0ae9b03292d");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
model = YOLO("yolov8n.pt")

results = model.train(
    data="maxar_solar.yaml",
    epochs=2,
    imgsz=416,
    batch=16,
    device="mps",
)
# Out:
# New https://pypi.org/project/ultralytics/8.0.234 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.232 🚀 Python-3.11.5 torch-2.1.2 MPS (Apple M2 Pro)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=maxar_solar.yaml, epochs=2, time=None, patience=50, batch=16, imgsz=416, save=True, save_period=-1, cache=False, device=mps, workers=8, project=None, name=train14, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train14
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]
# Model summary: 225 layers, 3011433 parameters, 3011417 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train14', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# train: Scanning /Users/sanjaboekle/Dropbox/12_Programmieren/0_WBS_data_science_bootcamp/10_final_project/solar_panel_object_detection/datasets/maxar_solar/train/labels.cache... 1767 images, 13 backgrounds, 0 corrupt: 100%|██████████| 1780/1780 [00:00<?, ?it/s]
# val: Scanning /Users/sanjaboekle/Dropbox/12_Programmieren/0_WBS_data_science_bootcamp/10_final_project/solar_panel_object_detection/datasets/maxar_solar/val/labels.cache... 254 images, 0 backgrounds, 0 corrupt: 100%|██████████| 254/254 [00:00<?, ?it/s]
# Plotting labels to runs/detect/train14/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# 2 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/2         0G       2.02      2.248      1.322         50        416: 100%|██████████| 112/112 [21:18<00:00, 11.41s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/8 [00:00<?, ?it/s]
# WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  12%|█▎        | 1/8 [01:11<08:19, 71.34s/it]
# WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  25%|██▌       | 2/8 [01:34<04:16, 42.83s/it]
# WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  38%|███▊      | 3/8 [01:58<02:52, 34.44s/it]
# WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50%|█████     | 4/8 [02:25<02:05, 31.36s/it]
# WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  62%|██████▎   | 5/8 [02:52<01:29, 29.96s/it]
# WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  75%|███████▌  | 6/8 [03:14<00:54, 27.08s/it]
# WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  88%|████████▊ | 7/8 [03:41<00:27, 27.25s/it]
# WARNING ⚠️ NMS time limit 2.000s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [04:30<00:00, 33.81s/it]
#                    all        254       5096     0.0373      0.066     0.0251     0.0162
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/2         0G      1.551       1.18        1.1         42        416: 100%|██████████| 112/112 [33:48<00:00, 18.11s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/8 [00:00<?, ?it/s]
# WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  12%|█▎        | 1/8 [00:25<03:00, 25.75s/it]
# WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  25%|██▌       | 2/8 [01:00<03:07, 31.25s/it]
# WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  38%|███▊      | 3/8 [01:19<02:08, 25.63s/it]
# WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50%|█████     | 4/8 [01:37<01:29, 22.42s/it]
# WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  62%|██████▎   | 5/8 [01:58<01:06, 22.09s/it]
# WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  75%|███████▌  | 6/8 [02:27<00:49, 24.51s/it]
# WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  88%|████████▊ | 7/8 [02:57<00:26, 26.28s/it]
# WARNING ⚠️ NMS time limit 2.000s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [03:25<00:00, 25.70s/it]
#                    all        254       5096     0.0323     0.0657     0.0224     0.0131
# 2 epochs completed in 1.056 hours.
# Optimizer stripped from runs/detect/train14/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train14/weights/best.pt, 6.2MB
#
# Validating runs/detect/train14/weights/best.pt...
# Ultralytics YOLOv8.0.232 🚀 Python-3.11.5 torch-2.1.2 MPS (Apple M2 Pro)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/8 [00:00<?, ?it/s]
# WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  12%|█▎        | 1/8 [00:37<04:25, 37.98s/it]
# WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  25%|██▌       | 2/8 [00:55<02:34, 25.75s/it]
# WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  38%|███▊      | 3/8 [01:00<01:21, 16.36s/it]
# WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50%|█████     | 4/8 [01:19<01:09, 17.35s/it]
# WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  62%|██████▎   | 5/8 [01:32<00:47, 15.78s/it]
# WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  75%|███████▌  | 6/8 [01:48<00:31, 15.83s/it]
# WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  88%|████████▊ | 7/8 [02:01<00:14, 14.89s/it]
# WARNING ⚠️ NMS time limit 2.000s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [02:36<00:00, 19.54s/it]
#                    all        254       5096     0.0349     0.0674     0.0251     0.0156
#            solar_panel        254       5087     0.0679     0.0236     0.0491     0.0302
#        not_solar_panel        254          9      0.002      0.111    0.00115   0.000921
# Speed: 22.3ms preprocess, 193.7ms inference, 0.0ms loss, 198.5ms postprocess per image
# Results saved to runs/detect/train14

# %%
Image(filename="runs/detect/train6/confusion_matrix.png")

# %%
Image(filename="runs/detect/train6/results.png")

# %%
# !yolo task=detect mode=val model=runs/detect/train6/weights/best.pt data=maxar_solar.yaml
# Out:
# Ultralytics YOLOv8.0.232 🚀 Python-3.11.5 torch-2.1.2 CPU (Apple M2 Pro)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /Users/sanjaboekle/Dropbox/12_Programmieren/0_WBS_data_science_boo
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        254       5096      0.839      0.191      0.264       0.15
#            solar_panel        254       5087      0.677      0.383       0.49      0.279
#        not_solar_panel        254          9          1          0      0.038       0.02
# Speed: 0.3ms preprocess, 95.4ms inference, 0.0ms loss, 2.2ms postprocess per image
# Results saved to runs/detect/val3
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model=runs/detect/train6/weights/
# Out:
# WARNING ⚠️ 'source' is missing. Using default 'source=/Users/sanjaboekle/anaconda3/envs/pytorch/lib/python3.11/site-packages/ultralytics/assets'.
# Ultralytics YOLOv8.0.232 🚀 Python-3.11.5 torch-2.1.2 CPU (Apple M2 Pro)
# Traceback (most recent call last):
#   File "/Users/sanjaboekle/anaconda3/envs/pytorch/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/Users/sanjaboekle/anaconda3/envs/pytorch/lib/python3.11/site-packages/ultralytics/cfg/__init__.py", line 448, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sanjaboekle/anaconda3/envs/pytorch/lib/python3.11/site-packages/ultralytics/engine/model.py", line 250, in predict
#     self.predictor.setup_model(model=self.model, verbose=is_cli)
#   File "/Users/sanjaboekle/anaconda3/envs/pytorch/lib/python3.11/site-packages/ultralytics/engine/predictor.py", line 320, in setup_model
#     self.model = AutoBackend(model or self.args.model,
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sanjaboekle/anaconda3/envs/pytorch/lib/python3.11/site-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sanjaboekle/anaconda3/envs/pytorch/lib/python3.11/site-packages/ultralytics/nn/autobackend.py", line 105, in __init__
#     fp16 &= pt or jit or onnx or xml or engine or nn_module or triton  # FP16
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: unsupported operand type(s) for &=: 'bool' and 'str'
